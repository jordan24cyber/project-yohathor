# %% [markdown]
# <a href="https://colab.research.google.com/github/jordan24cyber/project-yohathor/blob/main/tugas_5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load in

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt # data visualization
import seaborn as sns # statistical data visualization
# %matplotlib inline

# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# Any results you write to the current directory are saved as output.

# %%
import warnings

warnings.filterwarnings('ignore')

# %%
data = 'earthquake_alert_balanced_dataset.csv'

df = pd.read_csv(data, header=None)

# Remove the header row that was read as data
df = df.iloc[1:].copy()

# %%
# view dimensions of dataset

df.shape
# Out:
# (1300, 6)

# %%
# preview the dataset

df.head()
# Out:
#       0       1     2     3       4      5
# 1  7.00   14.00  8.00  7.00    0.00  green
# 2  6.90   25.00  4.00  4.00  -33.00  green
# 3  7.00  579.00  3.00  3.00  -13.00  green
# 4  7.30   37.00  5.00  5.00   65.00  green
# 5  6.60  624.00  0.00  2.00  -98.00  green

# %%
col_names = ['magnitude', 'depth', 'cdi', 'mmi', 'sig', 'alert']


df.columns = col_names

col_names
# Out:
# ['magnitude', 'depth', 'cdi', 'mmi', 'sig', 'alert']

# %%
# let's again preview the dataset

df.head()
# Out:
#   magnitude   depth   cdi   mmi     sig  alert
# 1      7.00   14.00  8.00  7.00    0.00  green
# 2      6.90   25.00  4.00  4.00  -33.00  green
# 3      7.00  579.00  3.00  3.00  -13.00  green
# 4      7.30   37.00  5.00  5.00   65.00  green
# 5      6.60  624.00  0.00  2.00  -98.00  green

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1300 entries, 1 to 1300
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   magnitude  1300 non-null   object
#  1   depth      1300 non-null   object
#  2   cdi        1300 non-null   object
#  3   mmi        1300 non-null   object
#  4   sig        1300 non-null   object
#  5   alert      1300 non-null   object
# dtypes: object(6)
# memory usage: 61.1+ KB

# %%
col_names = ['magnitude', 'depth', 'cdi', 'mmi', 'sig', 'alert']


for col in col_names:

    print(df[col].value_counts())
# Out:
# magnitude
# 6.50    103
# 6.60     83
# 6.90     70
# 6.70     53
# 6.80     48
#        ...
# 6.52      1
# 7.37      1
# 8.45      1
# 8.23      1
# 8.33      1
# Name: count, Length: 167, dtype: int64
# depth
# 10.00     120
# 9.00       75
# 12.00      71
# 11.00      61
# 13.00      53
#          ...
# 117.00      1
# 83.00       1
# 141.00      1
# 61.00       1
# 129.00      1
# Name: count, Length: 173, dtype: int64
# cdi
# 8.00    536
# 9.00    244
# 7.00    189
# 6.00    103
# 5.00     76
# 0.00     62
# 4.00     34
# 3.00     30
# 1.00     14
# 2.00     12
# Name: count, dtype: int64
# mmi
# 8.00    474
# 7.00    435
# 6.00    166
# 5.00     68
# 4.00     65
# 9.00     53
# 3.00     34
# 2.00      4
# 1.00      1
# Name: count, dtype: int64
# sig
# 93.00      25
# 26.00      23
# -118.00    22
# -115.00    18
# -98.00     18
#            ..
# -125.00     1
# 115.00      1
# 49.00       1
# -102.00     1
# 37.00       1
# Name: count, Length: 238, dtype: int64
# alert
# green     325
# yellow    325
# orange    325
# red       325
# Name: count, dtype: int64

# %%
df['alert'].value_counts()
# Out:
# alert
# green     325
# yellow    325
# orange    325
# red       325
# Name: count, dtype: int64

# %%
# check missing values in variables

df.isnull().sum()
# Out:
# magnitude    0
# depth        0
# cdi          0
# mmi          0
# sig          0
# alert        0
# dtype: int64

# %%
X = df.drop(['alert'], axis=1)

y = df['alert']

# %%
# split X and y into training and testing sets

from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.33, random_state = 42)

# %%
# check the shape of X_train and X_test

X_train.shape, X_test.shape
# Out:
# ((871, 5), (429, 5))

# %%
# check data types in X_train

X_train.dtypes
# Out:
# magnitude    object
# depth        object
# cdi          object
# mmi          object
# sig          object
# dtype: object

# %%
X_train.head()
# Out:
#      magnitude   depth   cdi   mmi      sig
# 320       7.10  434.00  3.00  6.00     8.00
# 1286      8.23   18.00  9.00  7.00     2.00
# 821       7.18    9.00  9.00  9.00    88.00
# 6         7.00  660.00  4.00  3.00   -13.00
# 101       6.50   12.00  8.00  8.00  -126.00

# %%
# import category encoders

import category_encoders as ce

# %%
# !pip install category_encoders
# Out:
# Requirement already satisfied: category_encoders in /usr/local/lib/python3.12/dist-packages (2.8.1)
# Requirement already satisfied: numpy>=1.14.0 in /usr/local/lib/python3.12/dist-packages (from category_encoders) (2.0.2)
# Requirement already satisfied: pandas>=1.0.5 in /usr/local/lib/python3.12/dist-packages (from category_encoders) (2.2.2)
# Requirement already satisfied: patsy>=0.5.1 in /usr/local/lib/python3.12/dist-packages (from category_encoders) (1.0.2)
# Requirement already satisfied: scikit-learn>=1.6.0 in /usr/local/lib/python3.12/dist-packages (from category_encoders) (1.6.1)
# Requirement already satisfied: scipy>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from category_encoders) (1.16.2)
# Requirement already satisfied: statsmodels>=0.9.0 in /usr/local/lib/python3.12/dist-packages (from category_encoders) (0.14.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.0.5->category_encoders) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.0.5->category_encoders) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.0.5->category_encoders) (2025.2)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=1.6.0->category_encoders) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=1.6.0->category_encoders) (3.6.0)
# Requirement already satisfied: packaging>=21.3 in /usr/local/lib/python3.12/dist-packages (from statsmodels>=0.9.0->category_encoders) (25.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas>=1.0.5->category_encoders) (1.17.0)

# %%
y_pred_gini = clf_gini.predict(X_test)

# %%
# instantiate the DecisionTreeClassifier model with criterion gini index

from sklearn.tree import DecisionTreeClassifier
clf_gini = DecisionTreeClassifier(criterion='gini', max_depth=3, random_state=0)


# fit the model
clf_gini.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(max_depth=3, random_state=0)

# %%
X_train.dtypes
# Out:
# magnitude    object
# depth        object
# cdi          object
# mmi          object
# sig          object
# dtype: object

# %%
# !pip install category_encoders
# Out:
# Requirement already satisfied: category_encoders in /usr/local/lib/python3.12/dist-packages (2.8.1)
# Requirement already satisfied: numpy>=1.14.0 in /usr/local/lib/python3.12/dist-packages (from category_encoders) (2.0.2)
# Requirement already satisfied: pandas>=1.0.5 in /usr/local/lib/python3.12/dist-packages (from category_encoders) (2.2.2)
# Requirement already satisfied: patsy>=0.5.1 in /usr/local/lib/python3.12/dist-packages (from category_encoders) (1.0.2)
# Requirement already satisfied: scikit-learn>=1.6.0 in /usr/local/lib/python3.12/dist-packages (from category_encoders) (1.6.1)
# Requirement already satisfied: scipy>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from category_encoders) (1.16.2)
# Requirement already satisfied: statsmodels>=0.9.0 in /usr/local/lib/python3.12/dist-packages (from category_encoders) (0.14.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.0.5->category_encoders) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.0.5->category_encoders) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.0.5->category_encoders) (2025.2)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=1.6.0->category_encoders) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=1.6.0->category_encoders) (3.6.0)
# Requirement already satisfied: packaging>=21.3 in /usr/local/lib/python3.12/dist-packages (from statsmodels>=0.9.0->category_encoders) (25.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas>=1.0.5->category_encoders) (1.17.0)

# %%
# encode variables with ordinal encoding

encoder = ce.OrdinalEncoder(cols=['magnitude', 'depth', 'cdi', 'mmi', 'sig'])


X_train = encoder.fit_transform(X_train)

X_test = encoder.transform(X_test)

# %%
X_train.head()
# Out:
#       magnitude  depth  cdi  mmi  sig
# 320           1      1    1    1    1
# 1286          2      2    2    2    2
# 821           3      3    2    3    3
# 6             4      4    3    4    4
# 101           5      5    4    5    5

# %%
X_test.head()
# Out:
#      magnitude  depth  cdi  mmi    sig
# 479       86.0    9.0    2  5.0   14.0
# 722       81.0    9.0    4  5.0  188.0
# 313       34.0    7.0    8  7.0   50.0
# 661       -1.0  121.0    4  5.0   17.0
# 824       68.0   25.0    4  5.0  137.0

# %%
# import DecisionTreeClassifier

from sklearn.tree import DecisionTreeClassifier

# %%
# instantiate the DecisionTreeClassifier model with criterion gini index

clf_gini = DecisionTreeClassifier(criterion='gini', max_depth=3, random_state=0)


# fit the model
clf_gini.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(max_depth=3, random_state=0)

# %%
y_pred_gini = clf_gini.predict(X_test)

# %%
from sklearn.metrics import accuracy_score

print('Model accuracy score with criterion gini index: {0:0.4f}'. format(accuracy_score(y_test, y_pred_gini)))
# Out:
# Model accuracy score with criterion gini index: 0.5804

# %%
y_pred_train_gini = clf_gini.predict(X_train)

y_pred_train_gini
# Out:
# array(['green', 'yellow', 'red', 'red', 'red', 'yellow', 'yellow',
#        'yellow', 'red', 'red', 'yellow', 'red', 'yellow', 'yellow', 'red',
#        'yellow', 'red', 'red', 'red', 'red', 'green', 'yellow', 'yellow',
#        'yellow', 'yellow', 'green', 'yellow', 'red', 'green', 'red',
#        'red', 'yellow', 'red', 'yellow', 'red', 'green', 'yellow', 'red',
#        'yellow', 'green', 'yellow', 'red', 'yellow', 'green', 'orange',
#        'yellow', 'green', 'yellow', 'yellow', 'orange', 'orange',
#        'yellow', 'green', 'green', 'yellow', 'red', 'orange', 'red',
#        'orange', 'red', 'yellow', 'yellow', 'red', 'yellow', 'red',
#        'yellow', 'yellow', 'red', 'yellow', 'red', 'orange', 'green',
#        'red', 'green', 'green', 'green', 'red', 'green', 'yellow',
#        'yellow', 'green', 'green', 'red', 'green', 'orange', 'orange',
#        'red', 'red', 'red', 'green', 'red', 'green', 'red', 'orange',
#        'yellow', 'yellow', 'orange', 'red', 'yellow', 'yellow', 'yellow',
#        'red', 'red', 'yellow', 'green', 'green', 'orange', 'yellow',
#        'red', 'green', 'yellow', 'red', 'red', 'green', 'yellow', 'red',
#        'red', 'red', 'yellow', 'orange', 'green', 'green', 'orange',
#        'yellow', 'yellow', 'yellow', 'red', 'orange', 'green', 'green',
#        'green', 'red', 'orange', 'yellow', 'green', 'yellow', 'orange',
#        'red', 'orange', 'yellow', 'red', 'green', 'red', 'yellow',
#        'green', 'green', 'red', 'red', 'yellow', 'red', 'yellow', 'green',
#        'orange', 'red', 'yellow', 'green', 'yellow', 'green', 'red',
#        'yellow', 'yellow', 'red', 'yellow', 'red', 'red', 'green',
#        'green', 'green', 'red', 'yellow', 'red', 'red', 'red', 'yellow',
#        'yellow', 'yellow', 'orange', 'red', 'red', 'yellow', 'yellow',
#        'green', 'green', 'red', 'green', 'yellow', 'yellow', 'yellow',
#        'green', 'green', 'yellow', 'green', 'yellow', 'red', 'red',
#        'green', 'yellow', 'orange', 'red', 'yellow', 'yellow', 'yellow',
#        'yellow', 'green', 'orange', 'yellow', 'yellow', 'green', 'yellow',
#        'red', 'red', 'red', 'green', 'red', 'yellow', 'orange', 'green',
#        'red', 'red', 'green', 'yellow', 'orange', 'red', 'yellow',
#        'yellow', 'orange', 'yellow', 'yellow', 'red', 'yellow', 'red',
#        'yellow', 'yellow', 'yellow', 'orange', 'yellow', 'green',
#        'yellow', 'green', 'yellow', 'red', 'yellow', 'orange', 'red',
#        'yellow', 'red', 'red', 'red', 'red', 'red', 'orange', 'orange',
#        'yellow', 'red', 'orange', 'red', 'yellow', 'red', 'red', 'red',
#        'red', 'green', 'red', 'yellow', 'red', 'yellow', 'yellow',
#        'green', 'green', 'orange', 'red', 'red', 'green', 'green',
#        'yellow', 'orange', 'yellow', 'orange', 'red', 'yellow', 'red',
#        'green', 'yellow', 'yellow', 'green', 'red', 'yellow', 'orange',
#        'yellow', 'yellow', 'yellow', 'green', 'orange', 'red', 'yellow',
#        'green', 'red', 'red', 'green', 'yellow', 'red', 'yellow',
#        'yellow', 'red', 'orange', 'red', 'green', 'yellow', 'red', 'red',
#        'yellow', 'red', 'red', 'orange', 'yellow', 'green', 'red',
#        'yellow', 'red', 'yellow', 'yellow', 'orange', 'yellow', 'yellow',
#        'red', 'red', 'yellow', 'red', 'red', 'red', 'yellow', 'yellow',
#        'orange', 'orange', 'yellow', 'green', 'yellow', 'orange', 'red',
#        'green', 'red', 'yellow', 'green', 'yellow', 'red', 'red', 'red',
#        'yellow', 'red', 'yellow', 'green', 'yellow', 'red', 'orange',
#        'orange', 'yellow', 'yellow', 'red', 'red', 'yellow', 'yellow',
#        'red', 'red', 'green', 'orange', 'red', 'green', 'red', 'yellow',
#        'yellow', 'red', 'yellow', 'red', 'yellow', 'green', 'green',
#        'green', 'yellow', 'red', 'yellow', 'red', 'orange', 'green',
#        'yellow', 'red', 'yellow', 'red', 'yellow', 'red', 'yellow', 'red',
#        'orange', 'red', 'yellow', 'green', 'yellow', 'yellow', 'red',
#        'yellow', 'green', 'green', 'red', 'yellow', 'green', 'red',
#        'yellow', 'yellow', 'yellow', 'green', 'yellow', 'orange',
#        'yellow', 'yellow', 'orange', 'yellow', 'yellow', 'yellow',
#        'green', 'yellow', 'green', 'yellow', 'green', 'red', 'red', 'red',
#        'red', 'yellow', 'red', 'green', 'red', 'green', 'red', 'yellow',
#        'yellow', 'orange', 'green', 'green', 'red', 'green', 'green',
#        'orange', 'red', 'yellow', 'red', 'red', 'yellow', 'green',
#        'yellow', 'green', 'yellow', 'yellow', 'green', 'yellow', 'yellow',
#        'yellow', 'orange', 'orange', 'red', 'orange', 'green', 'green',
#        'green', 'red', 'yellow', 'orange', 'red', 'green', 'yellow',
#        'green', 'red', 'green', 'yellow', 'red', 'yellow', 'yellow',
#        'yellow', 'yellow', 'red', 'red', 'yellow', 'red', 'red', 'green',
#        'orange', 'red', 'green', 'red', 'red', 'green', 'orange', 'red',
#        'yellow', 'green', 'orange', 'yellow', 'yellow', 'green', 'red',
#        'green', 'orange', 'yellow', 'orange', 'green', 'green', 'orange',
#        'red', 'red', 'red', 'red', 'orange', 'green', 'green', 'orange',
#        'red', 'yellow', 'green', 'green', 'orange', 'red', 'yellow',
#        'green', 'yellow', 'yellow', 'yellow', 'yellow', 'yellow', 'red',
#        'red', 'green', 'green', 'red', 'orange', 'green', 'orange',
#        'yellow', 'orange', 'yellow', 'orange', 'green', 'red', 'red',
#        'red', 'orange', 'red', 'green', 'yellow', 'orange', 'yellow',
#        'red', 'red', 'red', 'green', 'yellow', 'green', 'green', 'green',
#        'red', 'red', 'red', 'red', 'yellow', 'red', 'green', 'green',
#        'red', 'red', 'red', 'red', 'red', 'green', 'green', 'red',
#        'orange', 'red', 'red', 'green', 'yellow', 'green', 'red',
#        'orange', 'yellow', 'red', 'red', 'red', 'red', 'red', 'red',
#        'yellow', 'green', 'yellow', 'yellow', 'yellow', 'green', 'green',
#        'red', 'yellow', 'green', 'green', 'red', 'orange', 'green',
#        'orange', 'yellow', 'yellow', 'red', 'yellow', 'yellow', 'red',
#        'yellow', 'red', 'red', 'yellow', 'green', 'orange', 'yellow',
#        'orange', 'green', 'red', 'yellow', 'red', 'yellow', 'yellow',
#        'red', 'green', 'green', 'yellow', 'yellow', 'red', 'green', 'red',
#        'yellow', 'yellow', 'yellow', 'yellow', 'orange', 'green',
#        'yellow', 'red', 'yellow', 'green', 'orange', 'green', 'red',
#        'red', 'red', 'red', 'red', 'green', 'yellow', 'red', 'yellow',
#        'green', 'red', 'yellow', 'green', 'green', 'green', 'yellow',
#        'yellow', 'yellow', 'red', 'yellow', 'red', 'yellow', 'yellow',
#        'yellow', 'yellow', 'green', 'yellow', 'green', 'yellow', 'green',
#        'orange', 'orange', 'yellow', 'green', 'red', 'yellow', 'red',
#        'yellow', 'green', 'green', 'green', 'red', 'green', 'red',
#        'yellow', 'green', 'yellow', 'orange', 'red', 'red', 'red', 'red',
#        'orange', 'green', 'yellow', 'yellow', 'green', 'green', 'red',
#        'green', 'yellow', 'yellow', 'green', 'red', 'green', 'red',
#        'green', 'yellow', 'yellow', 'green', 'red', 'red', 'yellow',
#        'yellow', 'yellow', 'red', 'red', 'green', 'yellow', 'orange',
#        'red', 'red', 'yellow', 'yellow', 'green', 'orange', 'orange',
#        'red', 'yellow', 'red', 'red', 'green', 'orange', 'green',
#        'yellow', 'red', 'yellow', 'yellow', 'green', 'red', 'red', 'red',
#        'red', 'red', 'red', 'orange', 'yellow', 'red', 'red', 'green',
#        'yellow', 'yellow', 'red', 'red', 'red', 'red', 'red', 'yellow',
#        'green', 'red', 'green', 'red', 'green', 'yellow', 'yellow', 'red',
#        'green', 'green', 'yellow', 'green', 'red', 'orange', 'green',
#        'green', 'red', 'red', 'yellow', 'yellow', 'yellow', 'orange',
#        'red', 'yellow', 'green', 'red', 'yellow', 'yellow', 'orange',
#        'yellow', 'green', 'red', 'green', 'red', 'green', 'yellow',
#        'green', 'red', 'yellow', 'red', 'yellow', 'red', 'green', 'red',
#        'yellow', 'orange', 'red', 'green', 'red', 'yellow', 'yellow',
#        'red', 'orange', 'yellow', 'yellow', 'green', 'red', 'yellow',
#        'yellow', 'green', 'red', 'red', 'red', 'yellow', 'orange',
#        'green', 'yellow', 'green', 'orange', 'yellow', 'green', 'yellow',
#        'yellow', 'red', 'yellow', 'yellow', 'yellow', 'red', 'green',
#        'red', 'red', 'yellow', 'yellow', 'yellow', 'red', 'red', 'yellow',
#        'green', 'red', 'yellow', 'yellow', 'red', 'yellow', 'green',
#        'red', 'yellow', 'red', 'yellow', 'red', 'green', 'green',
#        'orange', 'green', 'red', 'green', 'green', 'green', 'yellow',
#        'red', 'red', 'yellow'], dtype=object)

# %%
print('Training-set accuracy score: {0:0.4f}'. format(accuracy_score(y_train, y_pred_train_gini)))
# Out:
# Training-set accuracy score: 0.5821

# %%
# print the scores on training and test set

print('Training set score: {:.4f}'.format(clf_gini.score(X_train, y_train)))

print('Test set score: {:.4f}'.format(clf_gini.score(X_test, y_test)))
# Out:
# Training set score: 0.5821
# Test set score: 0.5804

# %%
plt.figure(figsize=(12,8))

from sklearn import tree

tree.plot_tree(clf_gini.fit(X_train, y_train))
# Out:
# [Text(0.625, 0.875, 'x[3] <= 5.5\ngini = 0.75\nsamples = 871\nvalue = [211, 214, 219, 227]'),
#  Text(0.5, 0.625, 'x[3] <= 2.5\ngini = 0.74\nsamples = 788\nvalue = [128.0, 214.0, 219.0, 227.0]'),
#  Text(0.5625, 0.75, 'True  '),
#  Text(0.25, 0.375, 'x[3] <= 1.5\ngini = 0.663\nsamples = 408\nvalue = [99, 95, 22, 192]'),
#  Text(0.125, 0.125, 'gini = 0.499\nsamples = 114\nvalue = [60, 0, 0, 54]'),
#  Text(0.375, 0.125, 'gini = 0.652\nsamples = 294\nvalue = [39.0, 95.0, 22.0, 138.0]'),
#  Text(0.75, 0.375, 'x[1] <= 29.5\ngini = 0.619\nsamples = 380\nvalue = [29.0, 119.0, 197.0, 35.0]'),
#  Text(0.625, 0.125, 'gini = 0.527\nsamples = 287\nvalue = [6.0, 74.0, 181.0, 26.0]'),
#  Text(0.875, 0.125, 'gini = 0.666\nsamples = 93\nvalue = [23, 45, 16, 9]'),
#  Text(0.75, 0.625, 'gini = 0.0\nsamples = 83\nvalue = [83, 0, 0, 0]'),
#  Text(0.6875, 0.75, '  False')]

# %%
import graphviz
dot_data = tree.export_graphviz(clf_gini, out_file=None,
                              feature_names=X_train.columns,
                              class_names=y_train,
                              filled=True, rounded=True,
                              special_characters=True)

graph = graphviz.Source(dot_data)

graph

# %%
from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier(n_estimators=100, random_state=0)
rf.fit(X_train, y_train)
# Out:
# RandomForestClassifier(random_state=0)

# %%
# ==============================
# 🔹 PENDASULUAN / SETUP AWAL
# ==============================

# Import library dasar untuk analisis data dan visualisasi
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Supaya grafik tampil di notebook
# %matplotlib inline

# Mengabaikan warning agar output bersih
import warnings
warnings.filterwarnings('ignore')

# Cek direktori input (misalnya jika dijalankan di Kaggle/Colab)
import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# Nama file dataset
data = 'earthquake_alert_balanced_dataset.csv'

# Membaca dataset
df = pd.read_csv(data, header=None)

# Menghapus baris header yang terbaca sebagai data
df = df.iloc[1:].copy()

# Melihat dimensi dataset
print("Dimensi dataset:", df.shape)

# Menampilkan beberapa data awal
print(df.head())

# Menetapkan nama kolom
col_names = ['magnitude', 'depth', 'cdi', 'mmi', 'sig', 'alert']
df.columns = col_names

# Menampilkan daftar kolom
print("Kolom dataset:", df.columns.tolist())
# Out:
# Dimensi dataset: (1300, 6)
#       0       1     2     3       4      5
# 1  7.00   14.00  8.00  7.00    0.00  green
# 2  6.90   25.00  4.00  4.00  -33.00  green
# 3  7.00  579.00  3.00  3.00  -13.00  green
# 4  7.30   37.00  5.00  5.00   65.00  green
# 5  6.60  624.00  0.00  2.00  -98.00  green
# Kolom dataset: ['magnitude', 'depth', 'cdi', 'mmi', 'sig', 'alert']

# %%
# !pip install python-pptx
# Out:
# Collecting python-pptx
#   Downloading python_pptx-1.0.2-py3-none-any.whl.metadata (2.5 kB)
# Requirement already satisfied: Pillow>=3.3.2 in /usr/local/lib/python3.12/dist-packages (from python-pptx) (11.3.0)
# Collecting XlsxWriter>=0.5.7 (from python-pptx)
#   Downloading xlsxwriter-3.2.9-py3-none-any.whl.metadata (2.7 kB)
# Requirement already satisfied: lxml>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from python-pptx) (5.4.0)
# Requirement already satisfied: typing-extensions>=4.9.0 in /usr/local/lib/python3.12/dist-packages (from python-pptx) (4.15.0)
# Downloading python_pptx-1.0.2-py3-none-any.whl (472 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 472.8/472.8 kB 8.3 MB/s eta 0:00:00
# Downloading xlsxwriter-3.2.9-py3-none-any.whl (175 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 175.3/175.3 kB 8.1 MB/s eta 0:00:00
# Installing collected packages: XlsxWriter, python-pptx
# Successfully installed XlsxWriter-3.2.9 python-pptx-1.0.2

# %%
import graphviz
dot_data = tree.export_graphviz(clf_gini, out_file=None,
                              feature_names=X_train.columns,
                              class_names=y_train,
                              filled=True, rounded=True,
                              special_characters=True)

graph = graphviz.Source(dot_data)

graph

# %%
# instantiate the DecisionTreeClassifier model with criterion entropy

clf_en = DecisionTreeClassifier(criterion='entropy', max_depth=3, random_state=0)


# fit the model
clf_en.fit(X_train, y_train)

y_pred_en = clf_en.predict(X_test)

# %%
# instantiate the DecisionTreeClassifier model with criterion entropy

clf_en = DecisionTreeClassifier(criterion='entropy', max_depth=3, random_state=0)


# fit the model
clf_en.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy', max_depth=3, random_state=0)

# %%
from sklearn.metrics import accuracy_score

print('Model accuracy score with criterion entropy: {0:0.4f}'. format(accuracy_score(y_test, y_pred_en)))
# Out:
# Model accuracy score with criterion entropy: 0.5874

# %%
y_pred_train_en = clf_en.predict(X_train)

y_pred_train_en
# Out:
# array(['green', 'yellow', 'red', 'red', 'red', 'yellow', 'yellow',
#        'yellow', 'red', 'red', 'yellow', 'red', 'yellow', 'yellow', 'red',
#        'yellow', 'red', 'red', 'red', 'red', 'green', 'yellow', 'yellow',
#        'yellow', 'yellow', 'green', 'yellow', 'red', 'green', 'red',
#        'red', 'yellow', 'red', 'yellow', 'red', 'green', 'yellow', 'red',
#        'yellow', 'green', 'yellow', 'red', 'yellow', 'green', 'red',
#        'yellow', 'green', 'yellow', 'yellow', 'red', 'green', 'yellow',
#        'green', 'green', 'yellow', 'red', 'red', 'red', 'red', 'red',
#        'yellow', 'yellow', 'red', 'yellow', 'red', 'yellow', 'yellow',
#        'red', 'yellow', 'red', 'red', 'green', 'red', 'green', 'green',
#        'green', 'red', 'green', 'yellow', 'yellow', 'green', 'green',
#        'red', 'green', 'red', 'red', 'red', 'red', 'red', 'green', 'red',
#        'green', 'red', 'red', 'yellow', 'yellow', 'red', 'red', 'yellow',
#        'yellow', 'yellow', 'red', 'red', 'yellow', 'green', 'green',
#        'red', 'yellow', 'red', 'green', 'yellow', 'red', 'red', 'green',
#        'yellow', 'red', 'red', 'red', 'yellow', 'red', 'green', 'green',
#        'red', 'yellow', 'yellow', 'yellow', 'red', 'red', 'green',
#        'green', 'green', 'red', 'red', 'yellow', 'green', 'yellow', 'red',
#        'red', 'red', 'yellow', 'red', 'green', 'red', 'yellow', 'green',
#        'green', 'red', 'red', 'yellow', 'red', 'yellow', 'green', 'red',
#        'red', 'yellow', 'green', 'yellow', 'green', 'red', 'yellow',
#        'yellow', 'red', 'yellow', 'red', 'red', 'green', 'yellow',
#        'green', 'red', 'yellow', 'red', 'red', 'red', 'yellow', 'yellow',
#        'yellow', 'red', 'red', 'red', 'yellow', 'yellow', 'green',
#        'green', 'red', 'green', 'yellow', 'yellow', 'yellow', 'green',
#        'green', 'yellow', 'green', 'yellow', 'red', 'red', 'green',
#        'yellow', 'green', 'red', 'yellow', 'yellow', 'yellow', 'yellow',
#        'green', 'red', 'yellow', 'yellow', 'green', 'yellow', 'red',
#        'red', 'red', 'green', 'red', 'yellow', 'green', 'green', 'red',
#        'red', 'green', 'yellow', 'red', 'red', 'yellow', 'yellow', 'red',
#        'yellow', 'yellow', 'red', 'yellow', 'red', 'yellow', 'yellow',
#        'yellow', 'red', 'yellow', 'green', 'yellow', 'green', 'yellow',
#        'red', 'yellow', 'red', 'red', 'yellow', 'red', 'red', 'red',
#        'red', 'red', 'red', 'green', 'yellow', 'green', 'red', 'red',
#        'yellow', 'red', 'red', 'red', 'red', 'green', 'red', 'yellow',
#        'red', 'yellow', 'yellow', 'yellow', 'green', 'red', 'red', 'red',
#        'green', 'green', 'yellow', 'red', 'yellow', 'red', 'red',
#        'yellow', 'red', 'green', 'yellow', 'yellow', 'green', 'red',
#        'yellow', 'green', 'yellow', 'yellow', 'yellow', 'green', 'red',
#        'red', 'yellow', 'green', 'red', 'red', 'yellow', 'yellow', 'red',
#        'yellow', 'yellow', 'red', 'red', 'red', 'green', 'yellow',
#        'green', 'red', 'yellow', 'red', 'red', 'red', 'yellow', 'green',
#        'red', 'yellow', 'red', 'yellow', 'yellow', 'red', 'yellow',
#        'yellow', 'red', 'red', 'yellow', 'red', 'red', 'red', 'yellow',
#        'yellow', 'red', 'red', 'yellow', 'green', 'yellow', 'green',
#        'red', 'green', 'red', 'yellow', 'green', 'yellow', 'red', 'red',
#        'red', 'yellow', 'red', 'yellow', 'green', 'yellow', 'red', 'red',
#        'green', 'yellow', 'yellow', 'red', 'red', 'yellow', 'yellow',
#        'red', 'red', 'green', 'red', 'red', 'green', 'red', 'yellow',
#        'yellow', 'red', 'yellow', 'red', 'yellow', 'green', 'green',
#        'green', 'yellow', 'red', 'yellow', 'red', 'red', 'green',
#        'yellow', 'red', 'yellow', 'red', 'yellow', 'red', 'yellow', 'red',
#        'red', 'red', 'yellow', 'green', 'yellow', 'yellow', 'red',
#        'yellow', 'green', 'green', 'red', 'yellow', 'green', 'red',
#        'yellow', 'yellow', 'yellow', 'green', 'yellow', 'red', 'yellow',
#        'yellow', 'red', 'yellow', 'yellow', 'yellow', 'green', 'yellow',
#        'green', 'yellow', 'green', 'red', 'red', 'red', 'red', 'yellow',
#        'red', 'green', 'red', 'green', 'red', 'yellow', 'yellow', 'red',
#        'green', 'green', 'red', 'yellow', 'green', 'red', 'red', 'yellow',
#        'red', 'red', 'yellow', 'green', 'yellow', 'green', 'yellow',
#        'yellow', 'green', 'yellow', 'yellow', 'yellow', 'red', 'red',
#        'red', 'green', 'green', 'yellow', 'green', 'red', 'yellow', 'red',
#        'red', 'green', 'yellow', 'green', 'red', 'green', 'yellow', 'red',
#        'yellow', 'yellow', 'yellow', 'yellow', 'red', 'red', 'yellow',
#        'red', 'red', 'yellow', 'red', 'red', 'green', 'red', 'red',
#        'green', 'red', 'red', 'yellow', 'green', 'red', 'yellow',
#        'yellow', 'green', 'red', 'green', 'red', 'yellow', 'red', 'green',
#        'green', 'red', 'red', 'red', 'red', 'red', 'green', 'green',
#        'green', 'red', 'red', 'yellow', 'green', 'green', 'red', 'red',
#        'yellow', 'green', 'yellow', 'yellow', 'yellow', 'yellow',
#        'yellow', 'red', 'red', 'green', 'green', 'red', 'green', 'green',
#        'red', 'yellow', 'red', 'yellow', 'red', 'green', 'red', 'red',
#        'red', 'red', 'red', 'green', 'yellow', 'red', 'yellow', 'red',
#        'red', 'red', 'green', 'yellow', 'yellow', 'green', 'green', 'red',
#        'red', 'red', 'red', 'yellow', 'red', 'green', 'green', 'red',
#        'red', 'red', 'red', 'red', 'green', 'green', 'red', 'red', 'red',
#        'red', 'green', 'yellow', 'green', 'red', 'red', 'yellow', 'red',
#        'red', 'red', 'red', 'red', 'red', 'yellow', 'green', 'yellow',
#        'yellow', 'yellow', 'yellow', 'green', 'red', 'yellow', 'green',
#        'green', 'red', 'red', 'yellow', 'red', 'yellow', 'yellow', 'red',
#        'yellow', 'yellow', 'red', 'yellow', 'red', 'red', 'yellow',
#        'green', 'red', 'yellow', 'red', 'green', 'red', 'yellow', 'red',
#        'yellow', 'yellow', 'red', 'green', 'green', 'yellow', 'yellow',
#        'red', 'green', 'red', 'yellow', 'yellow', 'yellow', 'yellow',
#        'red', 'yellow', 'yellow', 'red', 'yellow', 'green', 'red',
#        'green', 'red', 'red', 'red', 'red', 'red', 'green', 'yellow',
#        'red', 'yellow', 'green', 'red', 'yellow', 'green', 'green',
#        'green', 'yellow', 'yellow', 'yellow', 'red', 'yellow', 'red',
#        'yellow', 'yellow', 'yellow', 'yellow', 'green', 'yellow', 'green',
#        'yellow', 'green', 'green', 'red', 'yellow', 'yellow', 'red',
#        'yellow', 'red', 'yellow', 'green', 'green', 'green', 'red',
#        'yellow', 'red', 'yellow', 'green', 'yellow', 'green', 'red',
#        'red', 'red', 'red', 'red', 'green', 'yellow', 'yellow', 'green',
#        'green', 'red', 'green', 'yellow', 'yellow', 'green', 'red',
#        'green', 'red', 'green', 'yellow', 'yellow', 'yellow', 'red',
#        'red', 'yellow', 'yellow', 'yellow', 'red', 'red', 'green',
#        'yellow', 'red', 'red', 'red', 'yellow', 'yellow', 'green', 'red',
#        'red', 'red', 'yellow', 'red', 'red', 'yellow', 'red', 'green',
#        'yellow', 'red', 'yellow', 'yellow', 'green', 'red', 'red', 'red',
#        'red', 'red', 'red', 'red', 'yellow', 'red', 'red', 'green',
#        'yellow', 'yellow', 'red', 'red', 'red', 'red', 'red', 'yellow',
#        'green', 'red', 'green', 'red', 'yellow', 'yellow', 'yellow',
#        'red', 'green', 'green', 'yellow', 'green', 'red', 'red', 'green',
#        'green', 'red', 'red', 'yellow', 'yellow', 'yellow', 'red', 'red',
#        'yellow', 'green', 'red', 'yellow', 'yellow', 'red', 'yellow',
#        'green', 'red', 'green', 'red', 'yellow', 'yellow', 'green', 'red',
#        'yellow', 'red', 'yellow', 'red', 'green', 'red', 'yellow',
#        'green', 'red', 'green', 'red', 'yellow', 'yellow', 'red', 'red',
#        'yellow', 'yellow', 'green', 'red', 'yellow', 'yellow', 'green',
#        'red', 'red', 'red', 'yellow', 'red', 'green', 'yellow', 'green',
#        'red', 'yellow', 'green', 'yellow', 'yellow', 'red', 'yellow',
#        'yellow', 'yellow', 'red', 'green', 'red', 'red', 'yellow',
#        'yellow', 'yellow', 'red', 'red', 'yellow', 'green', 'red',
#        'yellow', 'yellow', 'red', 'yellow', 'green', 'red', 'yellow',
#        'red', 'yellow', 'red', 'green', 'green', 'red', 'green', 'red',
#        'green', 'yellow', 'green', 'yellow', 'red', 'red', 'yellow'],
#       dtype=object)

# %%
print('Training-set accuracy score: {0:0.4f}'. format(accuracy_score(y_train, y_pred_train_en)))
# Out:
# Training-set accuracy score: 0.5855

# %%
# print the scores on training and test set

print('Training set score: {:.4f}'.format(clf_en.score(X_train, y_train)))

print('Test set score: {:.4f}'.format(clf_en.score(X_test, y_test)))
# Out:
# Training set score: 0.5855
# Test set score: 0.5874

# %%
plt.figure(figsize=(12,8))

from sklearn import tree

tree.plot_tree(clf_en.fit(X_train, y_train))
# Out:
# [Text(0.5769230769230769, 0.875, 'x[3] <= 2.5\nentropy = 1.999\nsamples = 871\nvalue = [211, 214, 219, 227]'),
#  Text(0.3076923076923077, 0.625, 'x[3] <= 1.5\nentropy = 1.724\nsamples = 408\nvalue = [99, 95, 22, 192]'),
#  Text(0.4423076923076923, 0.75, 'True  '),
#  Text(0.15384615384615385, 0.375, 'x[0] <= 61.5\nentropy = 0.998\nsamples = 114\nvalue = [60, 0, 0, 54]'),
#  Text(0.07692307692307693, 0.125, 'entropy = 0.959\nsamples = 97\nvalue = [60, 0, 0, 37]'),
#  Text(0.23076923076923078, 0.125, 'entropy = 0.0\nsamples = 17\nvalue = [0, 0, 0, 17]'),
#  Text(0.46153846153846156, 0.375, 'x[2] <= 3.5\nentropy = 1.705\nsamples = 294\nvalue = [39.0, 95.0, 22.0, 138.0]'),
#  Text(0.38461538461538464, 0.125, 'entropy = 1.434\nsamples = 47\nvalue = [7.0, 0.0, 16.0, 24.0]'),
#  Text(0.5384615384615384, 0.125, 'entropy = 1.557\nsamples = 247\nvalue = [32, 95, 6, 114]'),
#  Text(0.8461538461538461, 0.625, 'x[3] <= 5.5\nentropy = 1.805\nsamples = 463\nvalue = [112, 119, 197, 35]'),
#  Text(0.7115384615384615, 0.75, '  False'),
#  Text(0.7692307692307693, 0.375, 'x[2] <= 7.5\nentropy = 1.616\nsamples = 380\nvalue = [29.0, 119.0, 197.0, 35.0]'),
#  Text(0.6923076923076923, 0.125, 'entropy = 1.512\nsamples = 365\nvalue = [14, 119, 197, 35]'),
#  Text(0.8461538461538461, 0.125, 'entropy = 0.0\nsamples = 15\nvalue = [15, 0, 0, 0]'),
#  Text(0.9230769230769231, 0.375, 'entropy = 0.0\nsamples = 83\nvalue = [83, 0, 0, 0]')]

# %%
import graphviz
dot_data = tree.export_graphviz(clf_en, out_file=None,
                              feature_names=X_train.columns,
                              class_names=y_train,
                              filled=True, rounded=True,
                              special_characters=True)

graph = graphviz.Source(dot_data)

graph

# %%
# Print the Confusion Matrix and slice it into four pieces

from sklearn.metrics import confusion_matrix

cm = confusion_matrix(y_test, y_pred_en)

print('Confusion matrix\n\n', cm)
# Out:
# Confusion matrix
#
#  [[85  0 11 18]
#  [ 0  0 56 55]
#  [ 0  0 97  9]
#  [14  0 14 70]]

# %%
from sklearn.metrics import classification_report

print(classification_report(y_test, y_pred_en))
# Out:
#               precision    recall  f1-score   support
#
#        green       0.86      0.75      0.80       114
#       orange       0.00      0.00      0.00       111
#          red       0.54      0.92      0.68       106
#       yellow       0.46      0.71      0.56        98
#
#     accuracy                           0.59       429
#    macro avg       0.47      0.59      0.51       429
# weighted avg       0.47      0.59      0.51       429
